# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from spacy.en.word_sets import STOP_WORDS
from sklearn.preprocessing import scale, Normalizer

plt.style.use('fivethirtyeight')

# %%
df = pd.read_pickle('../pickle_files/df3.p')

# %%
mask = df['compound'] <= -0.4
negative_rows = df.loc[mask] 
mask = df['compound'] >= 0.7
positive_rows = df.loc[mask]
mask = (df['compound'] > -0.4) & (df['compound'] < 0.7)
neutral_rows = df.loc[mask]

# %%
print('negative tweets:', len(negative_rows))
print('neutral tweets:', len(neutral_rows))
print('positive_tweets:', len(positive_rows))
# Out:
# negative tweets: 10435
# neutral tweets: 44953
# positive_tweets: 6323

# %%
negative_rows.to_csv('../csvs/negative_rows.csv')
positive_rows.to_csv('../csvs/positive_rows.csv')

# %%
pd.read_csv('../csvs/negative_rows.csv', index_col='Unnamed: 0')
# Out:
#              Date           handle                        id language  \
# 3      2017-11-04  loooorenanicole  59fd32ff291ebbf619c97777       en
# 8      2017-11-04       _MisEllis_  59fd32ff291ebbf619c9777e       en
# 14     2017-11-04       _MisEllis_  59fd32ff291ebbf619c97786       en
# 17     2017-11-04  loooorenanicole  59fd32ff291ebbf619c9778b       en
# 24     2017-11-04    ItsKittyBabee  59fd32ff291ebbf619c97793       en
# 25     2017-11-04    sonja_travels  59fd32ff291ebbf619c97795       en
# 29     2017-11-04     Chris_Chuter  59fd32ff291ebbf619c9779b       en
# 32     2017-11-04    BramKincheloe  59fd32ff291ebbf619c9779f       en
# 37     2017-11-04        deetothab  59fd32ff291ebbf619c977a9       en
# 57     2017-11-04         AAforFun  59fd32ff291ebbf619c977cc       en
# 59     2017-11-04         nicburrr  59fd32ff291ebbf619c977ce       en
# 62     2017-11-04   EddieBMoneyhat  59fd32ff291ebbf619c977d5       en
# 79     2017-11-04         JennMaid  59fd3300291ebbf619c977ee       en
# 83     2017-11-04         nonstick  59fd3300291ebbf619c977fa       en
# 84     2017-11-04      KaseyPekala  59fd3300291ebbf619c977fc       en
# 96     2017-11-04          _Doc_FA  59fd3300291ebbf619c9780f       en
# 105    2017-11-04          simnett  59fd3300291ebbf619c9781d       en
# 108    2017-11-04        JussMari_  59fd3300291ebbf619c97821       en
# 112    2017-11-04    YoDreamBoyBMW  59fd3300291ebbf619c97825       en
# 115    2017-11-04      meatgroupie  59fd3300291ebbf619c97829       en
# 121    2017-11-04          DebasPh  59fd3300291ebbf619c97835       en
# 130    2017-11-04    JohnTheFluter  59fd3301291ebbf619c97845       en
# 140    2017-11-04         whizwhit  59fd3301291ebbf619c97853       en
# 143    2017-11-04         whizwhit  59fd3301291ebbf619c97857       en
# 146    2017-11-04     matheusaleex  59fd3301291ebbf619c9785b       en
# 147    2017-11-04          SawanSD  59fd3301291ebbf619c9785c       en
# 149    2017-11-04         CGal__oS  59fd3301291ebbf619c9785f       en
# 151    2017-11-04          SawanSD  59fd3301291ebbf619c97861       en
# 160    2017-11-04         CGal__oS  59fd3301291ebbf619c9786d       en
# 163    2017-11-04          v1talyg  59fd3301291ebbf619c97871       en
# ...           ...              ...                       ...      ...
# 96     @IrishMell @united Aggravating and unfair for ...
# 105    .@united no meal vouchers, no explanation for ...
# 108    I am very unhappy with @united Airlines. This ...
# 112    @united why is my plane delayed ABQ to DEN to ...
# 115    @_Doc_FA @united That happened to me, too. It’...
# 121                      @matheusaleex @united Realy sad
# 130    @united booked a flight for me and my gma-2 ad...
# 140    @united 7:37 a few pieces of broken plastic la...
# 143    A @united delay story:6:40 broken overhead bin...
# 146    @united It's so sad to see the 747 stop flying...
# 147    @united She arrived at 8am and was supposed to...
# 149    Alright last tweet on this madness but @united...
# 151    @united Can’t believe your horrible service. M...
# 160    @united is the WORST. 3hrs early for flight bu...
# 163    @united Have been taxiing for 30+ minutes, you...
# ...                                                  ...
# 61481  @AmericanAir Pt.3 was it my supposed privilege...
# 61490  @AmericanAir let us on the connecting flight s...
# 61496  @AmericanAir well the hits keep coming. Not on...
# 61505  @AmericanAir And if you're gonna have a shitty...
# 61506  @AmericanAir Per your suggest, I️ saved BP to ...
# 61507  @AmericanAir Then explain why the gate women a...
# 61514  aye yall broke my suitcase last night so WHO P...
# 61517  @thomascmost @AmericanAir Mines worse. Media p...
# 61521  @AmericanAir Heads up, that new carry on polic...
# 61528  @AmericanAir it's been 8 days since my mother'...
# 61530  Kiss of death. Should have just abandoned cart...
# 61531  @AmericanAir a cust relations rep called me 4 ...
# 61537  @NBCLA @AmericanAir @CityNewsService I'm annoy...
# 61544  Unbelievable - @NBCLA currently has this (pote...
# 61560  Wanted WATER as I entered the aircraft &amp; t...
# 61561  @AmericanAir is there a problem with seat maps...
# 61562  @AmericanAir is the absolute worst! Thankfully...
# 61563  @TerranceMalone @AmericanAir American is terri...
# 61567  @AmericanAir needs zero-tolerance on racist st...
# 61573  @AmericanAir, with no flights leaving hurrican...
# 61582  @AmericanAir epic fail pay for more legroom se...
# 61585  In spite of new planes (French airbus) @Americ...
# 61589  @AmericanAir you did it to me again!!! I gave ...
# 61590  @AmericanAir I'm having trouble selecting seat...
# 61607   @ReggieWayne_17 @AmericanAir 1st world problems.
# 61611  @AmericanAir and NAACP meet to discuss allegat...
# 61617  @ReggieWayne_17 @AmericanAir Just had the same...
# 61627  Two hours sitting on the planeon the tarmac. U...
# 61628  @AmericanAir When you have to land our plane e...
# 61632  @AmericanAir why the fuck aren’t you allowed t...
#
#                                                   tuples  \
# 3      ('support', 'in', 'shame', 'so', 'im', 'on', '...
# 8      ('just', 'this', 'is', 'but', 'that', 'truly',...
# 14     ('injury', 'missed', 'exams', 'multiple', 'we'...
# 17     ('perks', 'frustrated', 'with', 'supports', 'u...
# 24     ('extra', 'one', 'like', 'ur', 'last', 'take',...
# 25     ('with', 'amp', 'constant', 'of', 'had', 'in',...
# 29     ('rules', 'up', 'had', 'airports', 'from', 'se...
# 32     ('now', 'forced', 'us', 'put', 'so', 'flight',...
# 37           ('ruined', 'for', 'it', 'everybody', 'you')
# 57     ('oligopolistic', 'sadly', 'market', 'an', 'ar...
# 59     ('with', 'employees', 'consistently', 'worst',...
# 62     ('again', 'never', 'hate', 'for', 'either', 'i...
# 79     ('again', 'never', 'me', 'flights', 'for', 'de...
# 83     ('with', 'hey', 'canceling', 'flight', 'place'...
# 84     ('for', 'all', 'of', 'worst', 'service', 'to',...
# 96     ('for', 'aggravating', 'unfair', 'and', '#what...
# 105    ('for', 'flight', 'delayed', 'the', 'going', '...
# 108    ('airlines', 'first', 'with', 'this', 'is', 'l...
# 112    ('delayed', 'den', 'is', 'to', 'my', 'pdx', 'p...
# 115    ('happened', 'good', 'me', 'aggravating', 'not...
# 121                                     ('realy', 'sad')
# 130    ('for', 'her', 'adult', 'gma2', 'problem', 'fl...
# 140    ('bin', 'broken', 'pieces', 'later', 'is', 'th...
# 143    ('bin', 'broken', 'overhead', 'story640', 'tap...
# 146    ('times', 'queen', 'for', 'stop', 'but', 'its'...
# 147    ('now', 'what', 'its', '530pm', 'flight', 'the...
# 149    ('upgrade', 'tweet', 'madness', 'this', 'least...
# 151    ('visually', 'stuck', 'who', 'grandma', 'is', ...
# 160    ('for', 'carryon', 'but', 'worst', 'flight', '...
# 163    ('for', 'an', 'have', 'minutes', 'nope', 'thin...
# ...                                                  ...
# 61481  ('return', 'who', 'it', 'pt3', 'replaced', 'do...
# 61490  ('for', 'now', 'aa', 'dsw', 'terrible', 'us', ...
# 61496  ('now', 'arrival', 'connection', 'but', 'us', ...
# 61505  ('country', 'wave', 'if', 'agents', 'least', '...
# 61506  ('app', 'what', 'but', 'too', 'it', 'bp', 'so'...
# 61507  ('lambert', '50', 'not', 'the', 'then', 'at', ...
# 61514  ('aye', 'who', 'last', 'paying', 'night', 'bro...
# 61517  ('for', 'didnt', 'food', 'so', 'booze', 'mines...
# 61521  ('#shit', 'up', 'carry', 'is', 'that', 'new', ...
# 61528  ('patience', 'days', 'starting', '8', 'delayed...
# 61530  ('just', 'should', 'this', 'have', 'is', 'path...
# 61531  ('days', 'but', 'email', 'relations', 'cust', ...
# 61537  ('completely', 'for', 'aa', 'but', 'it', 'fix'...
# 61544  ('misleading', 'this', 'listeria', 'headline',...
# 61560  ('for', 'i', 'water', 'ewrclt', 'cups', 'kept'...
# 61561  ('relabeled', 'e175', 'with', 'aircraft', '4',...
# 61562  ('mistakes', 'thankfully', 'is', 'worst', 'the...
# 61563                     ('terrible', 'is', 'american')
# 61567  ('staff', 'ejecting', 'immediate', 'her', 'pil...
# 61573  ('for', 'had', 'impacted', 'way', 'can', '500'...
# 61582  ('for', 'now', 'up', '#wastedmoney', 'full', '...
# 61585  ('both', 'days', 'flights', 'still', 'terrible...
# 61589  ('it', 'worst', 'gave', 'i', 'did', 'flight', ...
# 61590  ('selecting', 'me', 'select', 'online', 'up', ...
# 61607                       ('world', 'problems', '1st')
# 61611  ('naacp', 'discuss', 'news', 'to', 'allegation...
# 61617  ('movie', 'just', 'same', 'with', 'closed', 'h...
# 61627  ('sitting', 'ugh', 'the', 'tarmac', 'planeon',...
# 61628  ('thats', 'goes', 'land', 'shock', 'have', 'ou...
# 61632  ('announce', 'with', 'for', 'flight', 'allergi...
#
#                                             tweets_clean  positive  negative  \
# 3       im so disappointed in your cust support shame...     0.145     0.427
# 8       this is just a gist of that debacle but ultim...     0.112     0.273
# 14      i missed multiple exams appointments and job ...     0.093     0.377
# 17      im really frustrated with your customer suppo...     0.113     0.242
# 24      need some extra boarding time youre the last ...     0.094     0.264
# 25      so very disappointed in handling of racial ex...     0.000     0.246
# 29      had to throw away stand up poster due to arbi...     0.097     0.219
# 32      so late that we missed our next flight you pu...     0.000     0.161
# 37                          you ruined it for everybody      0.000     0.341
# 57      sadly in an oligopolistic market consumers ar...     0.139     0.315
# 59      consistently the worst airline with the worst...     0.000     0.477
# 62      i hate you and i hate you never again for eit...     0.000     0.402
# 79      let me rephrase im never flying again delayed...     0.000     0.194
# 83      hey is it policy to threaten people with no p...     0.000     0.186
# 84      shoutout to for continuously having the worst...     0.000     0.255
# 96      aggravating and unfair for #payingfirstclass ...     0.000     0.431
# 105     united no meal vouchers no explanation for wh...     0.000     0.284
# 108     i am very unhappy with airlines this is my fi...     0.000     0.171
# 112           why is my plane delayed abq to den to pdx      0.000     0.235
# 115     that happened to me too its aggravating and r...     0.000     0.348
# 121                                           realy sad      0.000     0.508
# 130     booked a flight for me and my gma2 adult tick...     0.000     0.105
# 140     737 a few pieces of broken plastic later the ...     0.000     0.236
# 143     a delay story640 broken overhead bin duct tap...     0.000     0.435
# 146     its so sad to see the 747 stop flying but tim...     0.096     0.206
# 147     she arrived at 8am and was supposed to make a...     0.000     0.155
# 149     alright last tweet on this madness but at lea...     0.050     0.320
# 151     cant believe your horrible service my visuall...     0.000     0.256
# 160     is the worst 3hrs early for flight but basic ...     0.000     0.196
# 163     have been taxiing for 30 minutes youd think t...     0.000     0.175
# ...                                                  ...       ...       ...
# 61481   pt3 was it my supposed privilege who the hell...     0.074     0.243
# 61490   let us on the connecting flight still at the ...     0.000     0.188
# 61496   well the hits keep coming not only have you s...     0.031     0.194
# 61505   and if youre gonna have a shitty policy then ...     0.000     0.146
# 61506   per your suggest i️ saved bp to apple wallet ...     0.057     0.127
# 61507   then explain why the gate women at lambert ch...     0.000     0.186
# 61514   aye yall broke my suitcase last night so who ...     0.000     0.219
# 61517   mines worse media players didnt work for an h...     0.000     0.114
# 61521   heads up that new carry on policy is some #sh...     0.000     0.361
# 61528   its been 8 days since my mothers delayed bagg...     0.000     0.194
# 61530   kiss of death should have just abandoned cart...     0.123     0.480
# 61531   a cust relations rep called me 4 days ago and...     0.000     0.116
# 61537   im annoyed that my next flight wont have prop...     0.000     0.237
# 61544   unbelievable  currently has this potentially ...     0.074     0.227
# 61560   wanted water as i entered the aircraft amp th...     0.000     0.118
# 61561   is there a problem with seat maps on e175 air...     0.000     0.153
# 61562   is the absolute worst thankfully theres to fi...     0.150     0.369
# 61563                              american is terrible      0.000     0.437
# 61567   needs zerotolerance on racist staff incl pilo...     0.000     0.241
# 61573   with no flights leaving hurricane impacted is...     0.000     0.167
# 61582   epic fail pay for more legroom seat get on pl...     0.000     0.170
# 61531    0.884   -0.4380     0.0    0.0        0.0       1.0
# 61537    0.763   -0.9353     0.0    0.0        0.0       1.0
# 61544    0.699   -0.5754     0.0    0.0        0.0       1.0
# 61560    0.882   -0.4466     0.0    0.0        0.0       1.0
# 61561    0.847   -0.4696     0.0    0.0        0.0       1.0
# 61562    0.481   -0.6239     0.0    0.0        0.0       1.0
# 61563    0.563   -0.4767     0.0    0.0        0.0       1.0
# 61567    0.759   -0.6597     0.0    0.0        0.0       1.0
# 61573    0.833   -0.5267     0.0    0.0        0.0       1.0
# 61582    0.830   -0.5994     0.0    0.0        0.0       1.0
# 61585    0.673   -0.7777     0.0    0.0        0.0       1.0
# 61589    0.681   -0.8006     0.0    0.0        0.0       1.0
# 61590    0.779   -0.6597     0.0    0.0        0.0       1.0
# 61607    0.597   -0.4019     0.0    0.0        0.0       1.0
# 61611    0.728   -0.6249     0.0    0.0        0.0       1.0
# 61617    0.856   -0.4019     0.0    0.0        0.0       1.0
# 61627    0.763   -0.4215     0.0    0.0        0.0       1.0
# 61628    0.724   -0.8126     0.0    0.0        0.0       1.0
# 61632    0.857   -0.5423     0.0    0.0        0.0       1.0
#
#                                            tweets_clean1      time  \
# 3               i am disappointed customer support shame  03:22:11
# 8      gist debacle uimatelyi truly disappointed infu...  03:17:06
# 14     missed muiple exams appointments job opportuni...  03:12:25
# 17     i am really frustrated customer supports appar...  03:07:26
# 24     need extra boarding time you are last one plan...  03:03:15
# 25     disappointed handling racial exchange gate age...  03:02:58
# 29     throw away stand poster due arbitrary rules ai...  02:59:02
# 32     late missed next flight put us new flight sfo ...  02:56:52
# 37                                      ruined everybody  02:40:21
# 57     sadly oligopolistic market consumers inconveni...  02:09:22
# 59      consistently worst airline worst employees hands  02:08:19
# 62                                hate hate never either  02:03:14
# 79     let rephrase i am never flying delayed flights...  01:50:25
# 83     hey policy threaten people place sleep canceli...  01:41:36
# 84     shoutout continuously worst customer service time  01:39:35
# 96     aggravating unfair #payingfirstclass #whatsthe...  01:27:11
# 105    united meal vouchers explanation flight hours ...  01:17:07
# 108              unhappy airlines first last time flying  01:15:42
# 112                            plane delayed abq den pdx  01:13:50
# 115    happened aggravating really unfair foods even ...  01:11:27
# 121                                            realy sad  01:04:59
# 130    booked flight gma2 adu tickets realized senior...  00:52:05
# 140                pieces broken plastic later bin fixed  00:38:35
# 143    delay story640 broken overhead bin duct taped ...  00:35:43
# 146    sad see stop flying times change say good bye ...  00:33:40
# 147    arrived supposed make flight she is still sitt...  00:33:12
# 149    alright last tweet madness least give option p...  00:32:59
# 151    can not believe horrible service visually impa...  00:31:55
# 160    worst early flight basic economy means eligibl...  00:25:12
# 163    taxiing minutes you would think thered update ...  00:18:33
# ...                                                  ...       ...
# 61481  pt3 supposed privilege hell employ nasty peopl...  17:24:48
# 61490  let us connecting flight still gate stuck dsw ...  17:11:12
# 61496  well hits keep coming still able get us home s...  17:06:35
# 61505  you are gonna shitty policy least makeyour gat...  16:57:23
# 61617                                      NaN                   0
# 61627                                      NaN                   0
# 61628                                      NaN                   0
# 61632                                      NaN                   0
#
#                                        lemmatized_tweets
# 3                    disappointed customer support shame
# 8      gist debacle uimatelyi truly disappoint infuri...
# 14     miss muiple exam appointment job opportunity a...
# 17     frustrated customer support apparent lack unde...
# 24     ne extra boarding time plane time like punishm...
# 25     disappointed handle racial exchange gate agent...
# 29     throw away stand poster arbitrary rule airport...
# 32     late miss flight new flight sfo plane decomiss...
# 37                                        ruin everybody
# 57     sadly oligopolistic market consumer inconvenie...
# 59            consistently bad airline bad employee hand
# 62                                             hate hate
# 79     let rephrase fly delay flight muiple hour way fix
# 83     hey policy threaten people place sleep cancel ...
# 84       shoutout continuously bad customer service time
# 96       aggravate unfair payingfirstclass whatsthepoint
# 105    united meal voucher explanation flight hour de...
# 108                             unhappy airline time fly
# 112                              plane delay abq den pdx
# 115                    happen aggravate unfair food good
# 121                                            realy sad
# 130    book flight gma2 adu ticket realize senior opt...
# 140                    piece break plastic later bin fix
# 143           delay story640 break overhead bin duct tap
# 146          sad stop fly time change good bye queen air
# 147                    arrive suppose flight sit hell go
# 149    alright tweet madness option pay upgrade srsly...
# 151    believe horrible service visually impaired gra...
# 160    bad early flight basic economy mean eligible s...
# 163               taxi minute think update nope fly shit
# ...                                                  ...
# 61481  pt3 suppose privilege hell employ nasty people...
# 61490  let connect flight gate stuck dsw hour bc sani...
# 61496  hit come able home stuck gate equipment break ...
# 61505  gon na shitty policy makeyour gate agent imple...
# 61506  suggest i️ save bp apple wallet deny tsa chkpt...
# 61507  explain gate woman lambert charge guy new awfu...
# 61514                       aye break suitcase night pay
# 61517  mine bad media player work hour hour flight fr...
# 61521     head new carry policy shady shit greedy fucker
# 61528  day mother delay baggage new update patience s...
# 61530                   kiss death abandon cart pathetic
# 61531  customer relation representative call day ago ...
# 61537  annoyed flight proper cater big mess american ...
# 61544  unbelievable currently potentially libelous he...
# 61560  want water enter aircraft crew say cup keep th...
# 61561  problem seat map e175 aircraft operate republi...
# 61562                absolute bad thankfully fix mistake
# 61563                                  american terrible
# 61567  need zerotolerance racist staff incl pilot eje...
# 61573  flight leave hurricane impacted island charge ...
# 61582  epic fail pay legroom seat plane sit head bin ...
# 61585  spite new plane french airbu terrible flight d...
# 61589               give chance screw bad airline flight
# 61590  trouble select seat online error message pop t...
# 61607                                      world problem
# 61611   naacp meet discuss allegation racism herald news
# 61617      problem watch seat screen movie close caption
# 61627                        hour sit planeon tarmac ugh
# 61628  land plane early go anaphylactic shock lack ac...
# 61632  fuck allow announce customer eat peanut flight...
#
# [10712 rows x 20 columns]

# %%
label = ['negative rows', 'neutral rows', 'positive rows']
num_rows = [len(negative_rows), len(neutral_rows), len(positive_rows)]
for l, n in zip(label, num_rows):
    print('{0}: {1}'.format(l, n))
# Out:
# negative rows: 10435
# neutral rows: 44953
# positive rows: 6323

# %%
df.columns
# Out:
# Index(['Date', 'handle', 'id', 'language', 'tweet', 'tuples', 'tweets_clean',
#        'positive', 'negative', 'neutral', 'compound', 'United', 'Delta',
#        'Southwest', 'American', 'tweets_clean1', 'time', 'hashtags',
#        'Number of hashtags', 'lemmatized_tweets'],
#       dtype='object')

# %%
united_neg = negative_rows.loc[negative_rows['United'] == 1]
delta_neg = negative_rows.loc[negative_rows['Delta'] == 1]
sw_neg = negative_rows.loc[negative_rows['Southwest'] == 1]
aa_neg = negative_rows.loc[negative_rows['American'] == 1]

united_pos = positive_rows.loc[positive_rows['United'] == 1]
delta_pos = positive_rows.loc[positive_rows['Delta'] == 1]
sw_pos = positive_rows.loc[positive_rows['Southwest'] == 1]
aa_pos =  positive_rows.loc[positive_rows['American'] == 1]

# %%
airlines = ['United', 'Delta', 'Southwest', 'American']
neg_dfs = [united_neg, delta_neg, sw_neg, aa_neg]
pos_dfs = [united_pos, delta_pos, sw_pos, aa_pos]

# %%
stop = STOP_WORDS.union({'flight', 'amp', 'im', 'fly', 'flights'})
airline_stopwords = {'United': {'united'}, 
                  'Delta': {'delta', 'dea'},
                  'Southwest' : {'southwest'},
                  'American' : {'american', 'aa'}, 
                   }
all_stop = stop.union({'united', 'delta', 'dea', 'southwest', 'american', 
                       'aa', 'flight', 'amp', 'im', 'fly',
                      'good', 'thanks', 'great', 'thank', 'best', 
                       'like', 'awesome', 'today', 'airlines', 'better'})

# %% [markdown]
# #### SVD then clustering

# %%
def get_clusters_tfidf(airline, df, col, true_k = 5, n_components = 10, verbose = True, random_state = 24):
    vect = TfidfVectorizer(tokenizer = None,
                               max_df = 0.5, 
                               max_features = 200000, 
                               stop_words = all_stop,
                               use_idf = True, 
                               ngram_range=(1, 3),
                               min_df = 3)
    matrix = vect.fit_transform(df[col])
    grams = vect.get_feature_names()
    
    # do svd
    svd = TruncatedSVD(n_components = n_components, random_state = random_state)
    normalizer = Normalizer(copy=False)
    lsa = make_pipeline(svd, normalizer)
    reduced_matrix = lsa.fit_transform(matrix)
    
    # do kmeans
    km = KMeans(n_clusters = true_k, random_state = 24)
    km.fit(reduced_matrix)
    clusters = km.labels_.tolist()
    original_space_centroids = svd.inverse_transform(km.cluster_centers_)
    order_centroids = original_space_centroids.argsort()[:, ::-1]
    
    if verbose:
        original_space_centroids = svd.inverse_transform(km.cluster_centers_)
        order_centroids = original_space_centroids.argsort()[:, ::-1]
        print('\n', airline)
        for i in range(true_k):
            print("\nCluster %d:" % i)
            print(', '.join([grams[ind] for ind in order_centroids[i, :25]]))
    return km

# %%
kms_pos_tfidf_dict = {}
for airline, df in zip(airlines, pos_dfs):
    kms_pos_tfidf_dict[airline] = get_clusters_tfidf(airline, df, 'tweets_clean1', n_components = 10, 
                                                     true_k = 5, random_state = 42)
    df['cluster_num'] = kms_pos_tfidf_dict[airline].labels_ # append cluster number to df
# Out:
#  United
#
# Cluster 0:
# nice, love, trip, pretty, enjoy, plane, free, travel, amazing, flying, cool, ok, wow, know, got, day, happy, seat, glad, crew, thats, new, experience, class, work
#
# Cluster 1:
anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
kms_neg_tfidf_dict = {}
for airline, df in zip(airlines, neg_dfs):
    kms_neg_tfidf_dict[airline] = get_clusters_tfidf(airline, df, 'tweets_clean1', n_components = 10, 
                                                     true_k = 5, random_state = 42)
    df['cluster_num'] = kms_neg_tfidf_dict[airline].labels_ # append cluster number to df
# Out:
#  United
#
# Cluster 0:
# delayed, plane, delay, hour, hours, gate, hour delay, going, sitting, got, minutes, time, wait, min, broken, experience, missed, delayed hours, horrible, seat, miss, cancelled, ridiculous, sfo, ewr
#
# Cluster 1:
# time, bad, fuck, sad, suck, shit, gate, sorry, flying, experience, airline, cancelled, guys, disappointed, awful, plane, problem, check, know, sucks, try, boarding, miss, got, wrong
#
# Cluster 2:
# service, customer, customer service, worst customer, worst customer service, terrible, horrible, terrible customer service, terrible customer, flying, worst, seat, airline, absolutely, thats, bad, complaint, poor, guys, unacceptable, phone, customers, gate, rude, got
#
# Cluster 3:
# seat, flying, plane, check, gate, bag, horrible, hate, economy, worse, experience, carry, hell, time, seats, rude, pay, basic, wrong, basic economy, terrible, know, thats, got, lost
#
# Cluster 4:
# worst, airline, worst airline, flying, experience, hate, absolute, seat, worst customer, absolute worst, worst customer service, employees, service, flown, literally, people, terrible, fucking, bag, customer, airline flown, check, delayed, time, world
# /Users/eric/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#  Delta
#
# Cluster 0:
# time, bad, problem, flying, hate, thats, experience, hours, worst, disappointed, airline, need, bag, day, change, going, horrible, sorry, trying, error, know, got, wait, let, check
#
# Cluster 1:
# bomb, fuck, plane, bag, got, shit, gate, terrible, problem, bad, lost, let, going, know, need, wrong, luggage, guys, flying, check, experience, day, said, hey, head
#
# Cluster 2:
# service, customer, customer service, disappointed, terrible, rude, horrible, experience, worst, hold, worst customer, worst customer service, hour, delay, time, poor, phone, hours, wait, fuck, bad, minutes, response, worse, thats
#
# Cluster 3:
# delayed, hours, delay, plane, hour, delayed hours, stuck, connection, gate, atl, hr, minutes, missed, crew, missing, unacceptable, miss, late, waiting, airport, hour delay, home, broken, sitting, jfk
#
# Cluster 4:
# seat, seats, plane, broken, gate, worse, thats, got, paid, class, shame, upgrade, damn, terrible, people, rude, ridiculous, middle, change, flying, pay, minutes, getting, need, crew
# /Users/eric/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#  Southwest
#
# Cluster 0:
# bad, delay, worst, idea, experience, hell, hour, terrible, hour delay, gate, plane, airline, day, travel, way, disappointed, flying, terrible idea, bad experience, want, worst experience, awful, weather, hours, time
#
# Cluster 1:
# delayed, hours, delayed hours, plane, hey, got, delay, new, cancelled, time, know, problem, guys, gate, hour, connection, broken, bag, worst, bad, home, waiting, sad, lost, airline
#
# Cluster 2:
# /Users/eric/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# time, music, people, live, flying, hate, live music, want, fuck, airline, shit, listen, know, forced, going, way, think, got, bad, right, worse, sad, passengers, error, stop
#
# Cluster 3:
# service, customer, customer service, disappointed, horrible, terrible, worst, horrible customer service, horrible customer, know, rude, disappointing, wrong, going, time, lost, people, gate, poor, got, plane, disappointed customer, worst customer, worst customer service, disappointed customer service
#
# Cluster 4:
# wrong, plane, know, got, gate, error, problem, check, getting, bad, time, right, boarding, minutes, guys, people, let, bag, thats, sorry, hours, sad, trying, think, book
#
#  American
#
# Cluster 0:
# service, worst, customer, customer service, shit, airline, flying, bad, fuck, worst airline, time, worst customer, worst customer service, experience, rude, poor, terrible, horrible, air, gate, people, staff, poor customer, poor customer service, plane
#
# Cluster 1:
# unacceptable, airline, know, hate, thats, wrong, racism, way, need, stop, people, going, hell, luggage, gate, seat, bad, bag, problem, lost, shit, minutes, delay, customers, think
#
# Cluster 2:
# black, people, racist, racism, naacp, flying, black people, bad, problem, white, travel, passengers, know, disturbing, incidents, think, warns, warning, shame, issues, advisory, air, black passengers, need, disturbing incidents
#
# Cluster 3:
# gate, bag, problem, check, plane, bad, rude, seat, agent, carry, told, pay, ticket, going, unacceptable, flying, way, class, minutes, forced, boarding, lost, thats, need, staff
#
# Cluster 4:
# delayed, time, hours, plane, hour, delay, gate, terrible, delayed hours, cancelled, miss, waiting, wrong, minutes, stuck, going, airline, connection, got, home, problem, late, day, bags, missed
# /Users/eric/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
kmeans_neg_american = kms_neg_tfidf_dict['American']
pd.Series(kmeans_neg_american.labels_).value_counts()
# Out:
# 1    903
# 3    847
# 2    763
# 4    756
# 0    665
# dtype: int64

# %% [markdown]
# #### Map the clusters to the rows

# %%
rows_to_keep = ['Date', 'time', 'handle', 'tweet', 'compound', 'American', 'Delta', 'Southwest', 'United',
               'tweets_clean1', 'hashtags', 'cluster_num']
neg_dfs1 = []
for df in neg_dfs:
    df1= df.copy()
    df1 = df1[rows_to_keep]
    neg_dfs1.append(df1)

# %%
united_neg1 = neg_dfs1[0]
delta_neg1 = neg_dfs1[1]
sw_neg1 = neg_dfs1[2]
aa_neg1 = neg_dfs1[3]

# %%
for df in neg_dfs1:
    print(df.shape)
# Out:
# (2012, 12)
# (2871, 12)
# (2036, 12)
# (4070, 12)

# %%
aa_neg1.to_csv('../csvs/aa_neg.csv')
delta_neg1.to_csv('../csvs/delta_neg.csv')
sw_neg1.to_csv('../csvs/sw_neg.csv')
united_neg1.to_csv('../csvs/united_neg.csv')

# %%
pos_dfs1 = []
for df in pos_dfs:
    df1= df.copy()
    df1 = df1[rows_to_keep]
    pos_dfs1.append(df1)

# %%
united_pos1 = pos_dfs1[0]
delta_pos1 = pos_dfs1[1]
sw_pos1 = pos_dfs1[2]
aa_pos1 = pos_dfs1[3]

# %%
for df in pos_dfs1:
    print(df.shape)
# Out:
# (1347, 12)
# (2036, 12)
# (2014, 12)
# (1757, 12)

# %%
aa_pos1.to_csv('../csvs/aa_pos.csv')
delta_pos1.to_csv('../csvs/delta_pos.csv')
sw_pos1.to_csv('../csvs/sw_pos.csv')
united_pos1.to_csv('../csvs/united_pos.csv')
